# %%
import pandas as pd

# %%
stud0607 = pd.read_csv("../raw_data/0607student.txt")

# %%
list(stud0607.columns.values)
# Out:
# ['CAMPUS',
#  'BA0GH06N',
#  'BA0GM06N',
#  'BA0GR06N',
#  'BB0GR06N',
#  'BH0GR06N',
#  'BI0GR06N',
#  'BP0GR06N',
#  'BPEMALLP',
#  'BPERRA1R',
#  'BPERRA2R',
#  'BPERRA3R',
#  'BPERRA4R',
#  'BPERRA5R',
#  'BPERRA6R',
#  'BPERRA7R',
#  'BPERRA8R',
#  'BPERRAKR',
#  'BPERSA1R',
#  'BPERSA2R',
#  'BPERSA3R',
#  'BPERSA4R',
#  'BPERSA5R',
#  'BPERSA6R',
#  'BPERSA7R',
#  'BPERSA8R',
#  'BPERSAKR',
#  'BPETALLC',
#  'BPETBILP',
#  'BPETBLAP',
#  'BPETDISC',
#  'BPETDISP',
#  'BPETECOP',
#  'BPETG01P',
#  'BPETG02P',
#  'BPETG03P',
#  'BPETG04P',
#  'BPETG05P',
#  'BPETG06P',
#  'BPETG07P',
#  'BPETG08P',
#  'BPETG09P',
#  'BPETG10P',
#  'BPETG11P',
#  'BPETG12P',
#  'BPETGEEP',
#  'BPETGIFP',
#  'BPETGKNP',
#  'BPETGPKP',
#  'BPETHISP',
#  'BPETINDP',
#  'BPETLEPP',
#  'BPETPACP',
#  'BPETRSKP',
#  'BPETSPEP',
#  'BPETVOCP',
#  'BPETWHIP',
#  'BS0GR06N',
#  'BW0GR06N',
#  'CA0GH06N',
#  'CA0GM06N',
#  'CA0GR06N',
#  'CB0GR06N',
#  'CH0GR06N',
#  'CI0GR06N',
#  'CP0GR06N',
# ...

# %%
# include list of wanted columns here
stud0607chop = stud0607[[
    'CAMPUS',
'CPETBLAC',
'CPETHISC',
'CPETWHIC',
'CPETINDC',
'CPETPACC',
'CPETECOC',
'CPETLEPC',
'CPETDISC',
'CPETRSKC',
'CPEMALLC',
'CPETBLAP',
'CPETHISP',
'CPETWHIP',
'CPETINDP',
'CPETPACP',
'CPETECOP',
'CPETLEPP',
'CPETDISP',
'CPETRSKP',
'CPEMALLP',
'CB0GR06N',
'CH0GR06N',
'CW0GR06N',
'CI0GR06N',
'CP0GR06N',
'CPETBILC',
'CPETVOCC',
'CPETGIFC',
'CPETSPEC'
    ]]

# %%
stud0607chop
# Out:
#          CAMPUS  CPETBLAC  CPETHISC  CPETWHIC  CPETINDC  CPETPACC  CPETECOC  \
# 0       1902001        29         6       129         0         1        42
# 1       1902041        18         8       107         0         0        53
# 2       1902103        19        15       234         0         3       116
# 3       1903001        26        14       317         0         4       124
# 4       1903041        30        14       239         3         1       136
# 5       1903101        56        48       567         0         0       398
# 6       1904001        38        12       196         0         2       117
# 7       1904041        31        18       137         0         2        97
# 8       1904102        42        31       278         0         2       209
# 9       1906002        14         9       114         0         1        46
# 10      1906102        20         8       184         0         2        81
# ...

# %%
stud0607reaname = stud0607chop.rename(columns={
        'CPETBLAC':'newCPETBLAC'})
stud0607reaname
# Out:
#          CAMPUS  newCPETBLAC  CPETHISC  CPETWHIC  CPETINDC  CPETPACC  \
# 0       1902001           29         6       129         0         1
# 1       1902041           18         8       107         0         0
# 2       1902103           19        15       234         0         3
# 3       1903001           26        14       317         0         4
# 4       1903041           30        14       239         3         1
# 5       1903101           56        48       567         0         0
# 6       1904001           38        12       196         0         2
# 7       1904041           31        18       137         0         2
# 8       1904102           42        31       278         0         2
# 9       1906002           14         9       114         0         1
# 10      1906102           20         8       184         0         2
# 11      1907001          280       227       407         3         8
# 12      1907041          206       245       262         0         7
# ...

# %%
# Out:
#          CAMPUS  CPETBLAC  CPETHISC  CPETWHIC  CPETINDC  CPETPACC  CPETECOC  \
# 0       1902001        29         6       129         0         1        42
# 1       1902041        18         8       107         0         0        53
# 2       1902103        19        15       234         0         3       116
# 3       1903001        26        14       317         0         4       124
# 4       1903041        30        14       239         3         1       136
# 5       1903101        56        48       567         0         0       398
# 6       1904001        38        12       196         0         2       117
# 7       1904041        31        18       137         0         2        97
# 8       1904102        42        31       278         0         2       209
# 9       1906002        14         9       114         0         1        46
# 10      1906102        20         8       184         0         2        81
# ...
